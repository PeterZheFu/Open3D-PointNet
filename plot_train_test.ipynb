# %%
# %matplotlib inline
import pandas as pd

# %%
N = 50

# %%
log_xyz_train = pd.read_csv('log_records/log_xyz_train.csv')
a = log_xyz_train.iloc[0:N]
a
# Out:
#     Unnamed: 0    0     1         2         3        4
# 0            0  0.0   0.0  499.6875  2.780234  0.09375
# 1            1  0.0   1.0  499.6875  2.736789  0.15625
# 2            2  0.0   2.0  499.6875  2.352721  0.68750
# 3            3  0.0   3.0  499.6875  2.091003  0.71875
# 4            4  0.0   4.0  499.6875  1.989627  0.62500
# 5            5  0.0   5.0  499.6875  1.752644  0.71875
# 6            6  0.0   6.0  499.6875  1.377571  0.78125
# 7            7  0.0   7.0  499.6875  1.467254  0.75000
# 8            8  0.0   8.0  499.6875  1.134899  0.84375
# 9            9  0.0   9.0  499.6875  1.162988  0.78125
# 10          10  0.0  10.0  499.6875  0.848541  0.84375
# 11          11  0.0  11.0  499.6875  1.002424  0.78125
# 12          12  0.0  12.0  499.6875  1.126487  0.81250
# 13          13  0.0  13.0  499.6875  0.800370  0.87500
# 14          14  0.0  14.0  499.6875  0.833531  0.78125
# 15          15  0.0  15.0  499.6875  0.704910  0.84375
# ...

# %%
log_xyzs_train = pd.read_csv('log_records/log_xyzs_train.csv')
b = log_xyzs_train.iloc[0:N]['4']
b
# Out:
# 0     0.03125
# 1     0.34375
# 2     0.50000
# 3     0.71875
# 4     0.71875
# 5     0.75000
# 6     0.81250
# 7     0.84375
# 8     0.68750
# 9     0.81250
# 10    0.78125
# 11    0.81250
# 12    0.87500
# 13    0.90625
# 14    0.87500
# 15    0.87500
# 16    0.84375
# 17    0.87500
# 18    0.75000
# 19    0.84375
# 20    0.78125
# 21    0.84375
# 22    0.81250
# 23    0.81250
# 24    0.81250
# 25    0.81250
# 26    0.78125
# 27    0.75000
# 28    0.87500
# 29    0.78125
# 30    0.81250
# 31    0.90625
# 32    0.78125
# 33    0.90625
# 34    0.90625
# 35    0.87500
# 36    0.90625
# 37    0.96875
# 38    0.90625
# 39    0.71875
# 40    0.78125
# 41    0.81250
# 42    0.78125
# 43    0.90625
# 44    0.96875
# 45    0.87500
# 46    0.90625
# 47    0.96875
# 48    0.93750
# 49    0.87500
# Name: 4, dtype: float64

# %%
a['5'] = b
a
# Out:
# /home/peter/code/Open3D-PointNet/venv/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#     Unnamed: 0    0     1         2         3        4        5
# 0            0  0.0   0.0  499.6875  2.780234  0.09375  0.03125
# 1            1  0.0   1.0  499.6875  2.736789  0.15625  0.34375
# 2            2  0.0   2.0  499.6875  2.352721  0.68750  0.50000
# 3            3  0.0   3.0  499.6875  2.091003  0.71875  0.71875
# 4            4  0.0   4.0  499.6875  1.989627  0.62500  0.71875
# 5            5  0.0   5.0  499.6875  1.752644  0.71875  0.75000
# 6            6  0.0   6.0  499.6875  1.377571  0.78125  0.81250
# ...

# %%
a.rename(columns={ a.columns[4]: "your value" })
a.rename(columns={ a.columns[5]: "your value" })
a
# Out:
#     Unnamed: 0    0     1         2         3        4        5
# 0            0  0.0   0.0  499.6875  2.780234  0.09375  0.03125
# 1            1  0.0   1.0  499.6875  2.736789  0.15625  0.34375
# 2            2  0.0   2.0  499.6875  2.352721  0.68750  0.50000
# 3            3  0.0   3.0  499.6875  2.091003  0.71875  0.71875
# 4            4  0.0   4.0  499.6875  1.989627  0.62500  0.71875
# 5            5  0.0   5.0  499.6875  1.752644  0.71875  0.75000
# 6            6  0.0   6.0  499.6875  1.377571  0.78125  0.81250
# 7            7  0.0   7.0  499.6875  1.467254  0.75000  0.84375
# 8            8  0.0   8.0  499.6875  1.134899  0.84375  0.68750
# 9            9  0.0   9.0  499.6875  1.162988  0.78125  0.81250
# 10          10  0.0  10.0  499.6875  0.848541  0.84375  0.78125
# 11          11  0.0  11.0  499.6875  1.002424  0.78125  0.81250
# 12          12  0.0  12.0  499.6875  1.126487  0.81250  0.87500
# 13          13  0.0  13.0  499.6875  0.800370  0.87500  0.90625
# ...

# %%
a.plot(x='Unnamed: 0', y=['4', '5'], figsize=(15,10), grid=True)
